# %% [markdown]
# Problem Statement.
#
# A sequence of numbers is called an arithmetic progression if the difference between any two consecutive elements is the same.
#
# Given an array of numbers arr, return true if the array can be rearranged to form an arithmetic progression. Otherwise, return false.
#
#
#
# Example 1:
#
# Input: arr = [3,5,1]
# Output: true
# Explanation: We can reorder the elements as [1,3,5] or [5,3,1] with differences 2 and -2 respectively, between each consecutive elements.
#
# Example 2:
#
# Input: arr = [1,2,4]
# Output: false
# Explanation: There is no way to reorder the elements to obtain an arithmetic progression.
#
#
#
# Constraints:
#
#     2 <= arr.length <= 1000
#     -106 <= arr[i] <= 106

# %% [markdown]
# # Iteration - O(N) runtime, O(1) space

# %%
from typing import List

class Solution:
    def canMakeArithmeticProgression(self, arr: List[int]) -> bool:
        min_val, max_val, n = min(arr), max(arr), len(arr)
        if (max_val - min_val) % (n - 1): return False
        diff = (max_val - min_val) // (n - 1)
        i = 0

        while i < n:
            if arr[i] == min_val + i * diff: i += 1
            elif (arr[i] - min_val) % diff: return False
            else:
                j = (arr[i] - min_val) // diff
                if arr[j] == arr[i]: return False
                arr[i], arr[j] = arr[j], arr[i]

        return True

# %%
instance = Solution()
instance.canMakeArithmeticProgression([3,5,1])
# Out:
# True
